# %% [markdown]
# <a href="https://colab.research.google.com/github/pinkimahato9814-afk/test_march/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# print(" ".join(["a","b","c"]))
# a = [1,2]
# b= a.copy()
# b.append(3)
# print(a)

print(list("abc"))
# Out:
# ['a', 'b', 'c']

# %%
# print(5 == 5.0),true
#print(0.1+0.2 == 0.3),false
print( 5 is 5.0)
# Out:
# False
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# /tmp/ipykernel_19326/464173019.py:3: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   print( 5 is 5.0)

# %%
print(bool(None))
# Out:
# False

# %%
print({}.get("a")) # no value access
print({"a": 10}.get("a")) # with value acces
# Out:
# None
# 10

# %%
print("abc"[::-1])
# Out:
# cba

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(divmod(10,3))
# Out:
# (3, 1)

# %%
print(all([True,1,"abc"]))
# Out:
# True

# %%
print(any([0," ",False]))
# Out:
# True

# %%
print("hello pinki ji")
# Out:
# hello pinki ji

# %% [markdown]
# **my name is emrti**  **italicized text**
# ![Screenshot (1).png](data:image/png;base64,...)
#
# **bold text**

# %%
import pandas as pd
df = pd.read_csv("/content/sample_data/Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print("hello")
# Out:
# hello
